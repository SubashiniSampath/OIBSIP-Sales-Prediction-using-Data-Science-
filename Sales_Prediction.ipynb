# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Advertising.csv')

# %%
print(df)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df['Total_Advertising'] = df['TV'] + df['Radio'] + df['Newspaper']
df['TV_Radio'] = df['TV'] * df['Radio']

# %%
num_cols = ['Radio', 'Newspaper', 'Sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(df[num_cols], df['TV'], test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(y_pred)
# Out:
# [170.80160007 217.65434093 267.3049444  -27.47071516 258.90732725
#   78.22811009 230.44583863  83.14374058 170.29295746 166.26233618
#   59.14778276 108.82067175 173.98117417 -38.59310568 151.60748128
#  157.46956923 -30.24420762 196.2819906  106.3590671  224.90960881
#  219.75639302  67.48827126  29.95233314 252.06756591 109.01265743
#  110.95388443 221.9860609  167.24977829 123.3248954  -21.24919626
#  155.77417954 106.41509741 235.71949502 -27.35386274 218.58523367
#  235.18867714  19.8187213  253.06824342 138.65960012  89.87451042]

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print('Mean Squared Error: {:.2f}'.format(mse))
print('R2 Score: {:.2f}'.format(r2))
# Out:
# Mean Squared Error: 1112.10
# R2 Score: 0.86

# %%
# Plot the actual vs predicted values
plt.subplots(figsize=(10, 8))
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.xlabel('Predicted')
plt.ylabel('Residuals')
plt.axhline(y=0, color='red')
plt.show()

# %%
accuracy = r2_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.8638001225163752
